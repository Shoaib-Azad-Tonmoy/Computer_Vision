# %%
def bubblesort(numbers):
    for n in range(len(numbers) - 1, 0, -1):
        print(f"iteration {len(numbers) - n}:")
        print(numbers)
        for i in range(n):
            if numbers[i] > numbers[i + 1]:
                numbers[i], numbers[i + 1] = numbers[i + 1], numbers[i]
            print(f'step {i + 1}:')
            print(numbers)

        print("******************")
        print()

numbers = [34, 56, 23, 43, 57, 81, 28, 93, 51, 77]
print("Unsorted list is,")
print(numbers)
print()
bubblesort(numbers)
print("Sorted Array is, ")
print(numbers)
# Out:
# Unsorted list is,
# [34, 56, 23, 43, 57, 81, 28, 93, 51, 77]
#
# iteration 1:
# [34, 56, 23, 43, 57, 81, 28, 93, 51, 77]
# step 1:
# [34, 56, 23, 43, 57, 81, 28, 93, 51, 77]
# step 2:
# [34, 23, 56, 43, 57, 81, 28, 93, 51, 77]
# step 3:
# [34, 23, 43, 56, 57, 81, 28, 93, 51, 77]
# step 4:
# [34, 23, 43, 56, 57, 81, 28, 93, 51, 77]
# step 5:
# [34, 23, 43, 56, 57, 81, 28, 93, 51, 77]
# step 6:
# [34, 23, 43, 56, 57, 28, 81, 93, 51, 77]
# step 7:
# [34, 23, 43, 56, 57, 28, 81, 93, 51, 77]
# step 8:
# [34, 23, 43, 56, 57, 28, 81, 51, 93, 77]
# step 9:
# [34, 23, 43, 56, 57, 28, 81, 51, 77, 93]
# ******************
#
# iteration 2:
# [34, 23, 43, 56, 57, 28, 81, 51, 77, 93]
# step 1:
# [23, 34, 43, 56, 57, 28, 81, 51, 77, 93]
# step 2:
# [23, 34, 43, 56, 57, 28, 81, 51, 77, 93]
# step 3:
# [23, 34, 43, 56, 57, 28, 81, 51, 77, 93]
# step 4:
# [23, 34, 43, 56, 57, 28, 81, 51, 77, 93]
# step 5:
# [23, 34, 43, 56, 28, 57, 81, 51, 77, 93]
# step 6:
# [23, 34, 43, 56, 28, 57, 81, 51, 77, 93]
# step 7:
# [23, 34, 43, 56, 28, 57, 51, 81, 77, 93]
# step 8:
# [23, 34, 43, 56, 28, 57, 51, 77, 81, 93]
# ******************
#
# iteration 3:
# [23, 34, 43, 56, 28, 57, 51, 77, 81, 93]
# step 1:
# [23, 34, 43, 56, 28, 57, 51, 77, 81, 93]
# step 2:
# [23, 34, 43, 56, 28, 57, 51, 77, 81, 93]
# step 3:
# [23, 34, 43, 56, 28, 57, 51, 77, 81, 93]
# step 4:
# [23, 34, 43, 28, 56, 57, 51, 77, 81, 93]
# step 5:
# [23, 34, 43, 28, 56, 57, 51, 77, 81, 93]
# step 6:
# [23, 34, 43, 28, 56, 51, 57, 77, 81, 93]
# step 7:
# [23, 34, 43, 28, 56, 51, 57, 77, 81, 93]
# ******************
#
# iteration 4:
# [23, 34, 43, 28, 56, 51, 57, 77, 81, 93]
# step 1:
# [23, 34, 43, 28, 56, 51, 57, 77, 81, 93]
# step 2:
# [23, 34, 43, 28, 56, 51, 57, 77, 81, 93]
# step 3:
# [23, 34, 28, 43, 56, 51, 57, 77, 81, 93]
# step 4:
# [23, 34, 28, 43, 56, 51, 57, 77, 81, 93]
# step 5:
# [23, 34, 28, 43, 51, 56, 57, 77, 81, 93]
# step 6:
# [23, 34, 28, 43, 51, 56, 57, 77, 81, 93]
# ******************
#
# iteration 5:
# [23, 34, 28, 43, 51, 56, 57, 77, 81, 93]
# step 1:
# [23, 34, 28, 43, 51, 56, 57, 77, 81, 93]
# step 2:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# step 3:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# step 4:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# step 5:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# ******************
#
# iteration 6:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# step 1:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# step 2:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# step 3:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# step 4:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# ******************
#
# iteration 7:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# step 1:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# step 2:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# step 3:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# ******************
#
# iteration 8:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# step 1:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# step 2:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# ******************
#
# iteration 9:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# step 1:
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]
# ******************
#
# Sorted Array is,
# [23, 28, 34, 43, 51, 56, 57, 77, 81, 93]

# %%
def merge(arr, l, m, r):
    n1 = m - l + 1
    n2 = r - m

    L = [0] * (n1)
    R = [0] * (n2)

    for i in range(0, n1):
        L[i] = arr[l + i]

    for j in range(0, n2):
        R[j] = arr[m + 1 + j]

    i = 0
    j = 0
    k = l

    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1


    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1

    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1
    print(f'step ----- Left: {L} and Right: {R}')
    print()

def mergeSort(arr, l, r):
    if l < r:
        m = l + (r - l) // 2

        mergeSort(arr, l, m)
        mergeSort(arr, m + 1, r)
        merge(arr, l, m, r)

arr = [12, 11, 13, 5, 6, 7, 34, 3, 67, 45]
n = len(arr)
print("Given array is")
for i in range(n):
    print("%d" % arr[i], end=" ")
print()

mergeSort(arr, 0, n - 1)
print("\n\nSorted array is")
for i in range(n):
    print("%d" % arr[i], end=" ")
# Out:
# Given array is
# 12 11 13 5 6 7 34 3 67 45
# step ----- Left: [12] and Right: [11]
#
# step ----- Left: [11, 12] and Right: [13]
#
# step ----- Left: [5] and Right: [6]
#
# step ----- Left: [11, 12, 13] and Right: [5, 6]
#
# step ----- Left: [7] and Right: [34]
#
# step ----- Left: [7, 34] and Right: [3]
#
# step ----- Left: [67] and Right: [45]
#
# step ----- Left: [3, 7, 34] and Right: [45, 67]
#
# step ----- Left: [5, 6, 11, 12, 13] and Right: [3, 7, 34, 45, 67]
#
#
#
# Sorted array is
# 3 5 6 7 11 12 13 34 45 67
